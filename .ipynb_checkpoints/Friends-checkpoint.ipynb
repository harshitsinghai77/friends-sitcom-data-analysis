# %%
import os
import pandas as pd
import re
from textblob import TextBlob
import sqlite3
import matplotlib
import matplotlib.pyplot as plt
matplotlib.font_manager._rebuild()
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina', quality=100)
import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager
font_manager._rebuild()

# %%
BASE_URL = 'dataset/'

master_array = []

for filename in os.listdir(BASE_URL):
    
    f = open(BASE_URL+filename, "r", encoding='utf-8')
    
    split_name = filename.split('.') #obtain the season and episodes
    season = split_name[0]   
    episode = split_name[1]
    
    script = f.read() #read the script file
    pattern = re.compile(r'\s(?=\w+(?=:))') # store the regex
    result = re.split(pattern, script) # split the script where our pattern matched (pink dot)
    
    for item in result:
        split_line = item.split(':')
        try:
            character = split_line[0]
            speech = split_line[1]
            master_array.append([season, episode, character, speech])
        except:
            pass

# %%
df = pd.DataFrame(master_array, columns=['season', 'episode', 'char', 'line'])
df
# Out:
#       season episode    char  \
# 0          1       1      by
# 1          1       1      by
# 2          1       1      by
# 3          1       1  Monica
# 4          1       1    Joey
# ...      ...     ...     ...
# 61845      9       9   Scene
# 61846      9       9    ROSS
# 61847      9       9    MIKE
# 61848      9       9  PHOEBE
# 61849      9       9    MIKE
#
#                                                     line
# 0              Marta Kauffman & David Crane\nTranscribed
# 1                     guineapig\nAdditional transcribing
# 2                                      Eric Aasen\n(Note
# 3       There's nothing to tell! He's just some guy\n...
# 4       C'mon, you're going out with the guy! There's...
# ...                                                  ...
# 61845   Central Perk.� Phoebe and Mike are on the sof...
# 61846                          Hey you guys.� (He sits.)
# 61847                                               Hey.
# 61848   Hey.� I'll be right back.� I've got to go to ...
# 61849   (finally) Stout.� That's a kind of beer.\n(Ro...
#
# [61850 rows x 4 columns]

# %% [markdown]
# #### Droping all of these rows by removing the character 'by'

# %%
df = df[df.char != 'by']
df
# Out:
#       season episode      char  \
# 3          1       1    Monica
# 4          1       1      Joey
# 5          1       1  Chandler
# 6          1       1    Phoebe
# 7          1       1    Phoebe
# ...      ...     ...       ...
# 61845      9       9     Scene
# 61846      9       9      ROSS
# 61847      9       9      MIKE
# 61848      9       9    PHOEBE
# 61849      9       9      MIKE
#
#                                                     line
# 3       There's nothing to tell! He's just some guy\n...
# 4       C'mon, you're going out with the guy! There's...
# 5       All right Joey, be\nnice.  So does he have a ...
# 6       Wait, does he eat chalk?\n(They all stare, be...
# 7       Just, 'cause, I don't want her to go through\...
# ...                                                  ...
# 61845   Central Perk.� Phoebe and Mike are on the sof...
# 61846                          Hey you guys.� (He sits.)
# 61847                                               Hey.
# 61848   Hey.� I'll be right back.� I've got to go to ...
# 61849   (finally) Stout.� That's a kind of beer.\n(Ro...
#
# [61352 rows x 4 columns]

# %%
df['char'].unique()
# Out:
# array(['Monica', 'Joey', 'Chandler', 'Phoebe', 'All', 'Ross', '3',
#        'Rachel', 'Waitress', 'me', 'Paul', '6', 'TV', 'Frannie',
#        'Customer', 'holiday', 'Max', 'David', 'Janice', 'Sandy', 'Bobby',
#        'Clark', 'Street', 'Guy', 'Leno', 'Paolo', 'Bing', 'Carol',
#        'Susan', 'Assistant', '4', '5', 'continues', 'Guys', 'Girls', '2',
#        'Roger', 'Tribbiani', 'Ronni', 'stop', 'Woman', 'Lorraine',
#        'Kristin', '1', 'something', 'Tedlock', 'Celia', 'Steve', 'Ursula',
#        'Teacher', 'Helen', 'Nina', 'Douglas', 'Jamie', 'Fran', 'voice',
#        '13', 'tip', 'Nurse', 'Mitchell', 'Rosen', 'Party', 'Friends',
#        'Geller', 'Iris', 'Note', 'have', 'Heckles', 'Intercom', 'Luisa',
#        'Both', 'Barry', 'advice', 'Marsha', 'Robbie', 'Bernice',
#        'Oberman', 'Mindy', 'letters', 'this', 'Danielle', 'Baldhara',
#        'PA', 'Actor', 'Ethan', 'thinking', 'Gerston', 'Santos', 'Petrie',
#        'Franzblau', 'Lydia', 'Janitor', 'Melanie', 'Attendant', 'Man',
#        'Carl', 'Julie', 'Paula', 'you', 'Alan', 'question', 'Lizzie',
#        'out', 'Leslie', 'Kiki', 'Joanne', 'Receptionist', 'Kid', 'Pheebs',
#        'Angela', 'Bob', 'Aurora', 'stuff', 'Director', 'way', 'Jill',
#        'note', 'From', 'Shelley', 'Lillian', 'Andrea', 'Lowell', 'Terry',
#        'Girl', 'says', 'follows', 'Charlie', 'Mike', 'Precious', 'thing',
#        '\n\nFriends - 10.10 - The One Where Chandler Gets Caught\n\n\n<!--\n\tbody {\n\t\tposition     ',
#        'was',
#        '\n\nFriends - 10.11 - The One Where The Stripper Cries\n\n\n<!--\n\tbody {\n\t\tposition     ',
#        'Missy', 'Voice', 'Osmond', 'Donny', 'Gene', 'appears', 'stripper',
#        'Roy', 'word', 'Henrietta', 'Adrienne', 'scene', 'song', 'guy',
#        "\n\nFriends - 10.12 - The One With Phoebe's Wedding\n\n\n<!--\n\tbody {\n\t\tposition     ",
#        'mother', 'father', 'mom', 'dad',
#        '\n\nFriends - 10.13 - The One Where Joey Speaks French\n\n\n<!--\n\tbody {\n\t\tposition     ',
#        'Erica', 'Green', 'Tape', 'assistant',
#        '\n\nFriends - 10.14 - The One With Princess Consuela\n\n\n<!--\n\tbody {\n\t\tposition     ',
#        'Zellner', 'Campbell', 'Clerk', 'Gunther', 'Realtor', 'Meet',
#        'Mackenzie', 'Mark', 'Rita',
#        '\n\nFriends - 10.15- The One Where Estelle Dies\n\n\n<!--\n\tbody {\n\t\tposition     ',
#        'Jennifer', 'Zelner', 'it', 'Lady', 'machine',
#        "\n\nFriends - 10.16 - The One With Rachel's Going Away Party\n\n\n<!--\n\tbody {\n\t\tposition     ",
#        'enjoy', 'Everybody',
#        '\n\nFriends - 10.17-10.18 - The Last One\n\n\n<!--\n\tbody {\n\t\tposition     ',
#        'Doctor', 'agent', '8', 'stewardess', 'Colleen', 'Bill', 'Owen',
#        "\n\nFriends - 1003 - The One With Ross' Tan\n\n\n<!--body {  position     ",
#        'Amanda', 'first', 'Glenda',
#        '\n\n\n\nFriends - 1004 - The One With The Cake\n\n<!--body {  position     ',
#        'Judy', 'Jack', 'Estelle', 'Scene', 'Emma',
#        "\n\n\nFriends - 10.05 The One Where Rachel's Sister Baby-sits\n\n<!--body {  position     ",
#        'Amy', 'Announcer', 'thought',
#        "\n\n\nFriends - 10.06 - The One With Ross' Grant\n\n<!--body {  position     ",
#        'Benjamin', 'Li', 'Biely', 'commercial',
#        '\n\n\nFriends - 10.07 The One With The Home Study\n\n<!--body {  position     ',
#        'children', 'Laura',
#        '\n\nFriends - 10.08 The One With The Late Thanksgiving\n\n\n<!--\n\tbody {  \n\t\tposition     ',
#        'Host', 'like', 'beautiful',
#        '\n\nFriends - 10.09 - The One With The Birth Mother\n\n\n<!--body {  position     ',
#        'Waiter', 'Sarah', 'Paulo', 'Frankie', 'RACH', 'JOEY', 'MNCA',
#        'PHOE', 'CHAN', 'ROSS', 'FBOB', 'ALL', 'RUSS', 'ESTL', 'WAITER',
#        'GANG', 'JULIE', 'CAROL', 'SUSAN', 'MONICA', 'CHANDLER', 'RACHEL',
#        'WALLACE', 'PHOEBE', 'GREEN', 'A', 'MINISTER', 'WOMAN',
#        '\n\nThe One After the Superbowl\n\n\nThe One After the Superbowl\n\n\nOriginally written by Michael Borkow, Mike Sikowitz & Jeffrey Astrof \nTranscribed by Joshua Hodge.\nMinor additions and adjustments by Dan Silverstein.\n\n\n[Scene',
#        'VOICEOVER', 'ROB', 'ERICA', 'LIPSON', 'KIDS', 'JANITOR', 'DOCTOR',
#        'KID', 'GUARD', 'TRAINER', 'ASSISTANT', 'SUSIE', 'DAMME',
#        'DIRECTOR', 'NOTE', 'INTERVIEWER', 'GELLER', 'GAIL', 'MAN', 'ROY',
#        'CHIP', 'BOTH',
#        '\n\nThe One Where Ross and Rachel...You Know\n\n\nThe One Where Rachel and Ross... You Know\n\n\nOriginally written by \nTranscribed by Joshua Hodge\nMinor additions and adjustments by Dan Silverstein.\n\n\n\n[Scene',
#        'chandler', 'BURKE', 'GUY',
#        '\n\nThe One Where Joey Moves Out\n\n\nThe One Where Joey Moves Out\n\n\nOriginally written by Betsy Bornes\nTranscribed by Joshua Hodge.\nMinor additions and adjustments by Dan Silverstein.\n\n\n[Scene',
#        'RICHARD', 'FRIEND', 'ARTIST',
#        '\n\nThe One Where Eddie Moves In\n\n\nThe One Where Eddie Moves In\n\n\nOriginally written by Adam Chase.\nTranscribed by Joshua Hodge.\n\n\n[Scene',
#        'PRODUCER', 'EDDIE',
#        '\n\nThe One Where Dr. Remore Dies\n\n\nThe One Where Dr. Remore Dies\n\n\nOriginally written by ???.\nTranscribed by Josh Hodge.\n\n\n[Scene',
#        'AMBER', 'REMORE', 'TILLY', 'WRITER', 'HORTON', 'INTERCOM',
#        'AMGER',
#        "\n\nThe One Where Eddie Won't Go\n\n\nThe One Where Eddie Won't Go\n\n\nOriginally written by .\nTranscribed by Joshua Hodge.\n\n\n[Scene",
#        'ESTELLE', 'GUNTHER', 'MOVER',
#        '\n\nThe One Where Old Yeller Dies\n\n\nThe One Where Old Yeller Dies\n\n\nOriginally written by .\nTranscribed by Joshua Hodge.\n\n\n[Scene',
#        'BEN', 'ERNIE', 'Annabelle',
#        '\n\nThe One With the Two Bullies\n\n\nThe One With the Two Bullies\n\n\nOriginally written by Sebastian Jones and Brian Buckner.\nTranscribed by Joshua Hodge.\n\n\n[Scene',
#        'EVERYONE', 'BULLY', 'BUFFAY', 'FRANK',
#        '\n\nThe One With the Two Parties\n\n\nThe One With the Two Parties\n\n\nOriginally written by Alexa Junge.\nTranscribed by Joshua Hodge.\n\n\n[Scene',
#        'GREENE', 'VOICE', 'GUNTER', 'GUYS',
#        '\n\nThe One With the Chicken Pox\n\n\nThe One With the Chicken Pox\n\n\nOriginally written by Brown Mandell.\nTranscribed by Joshua Hodge.\n\n\n[Scene',
#        'SCOTT', 'RYAN', 'JEANNIE', 'DOUGLAS',
#        "\n\nThe One With Barry and Mindy's Wedding\n\n\nThe One With Barry and Mindy's Wedding\n\nOriginally written by Ira Ungerleider.\nTeleplay by Brown Mandell.\nTranscribed by Eric B Aasen.\nHTMLed by guineapig. \n\n\n[Scene",
#        'PLANNER', 'WINEBURG', 'MINDY', 'BARRY', '9', 'JANICE', 'HECKLES',
#        'TREEGER', 'BOYLE', 'ALISON', 'her',
#        "\n\nThe One With Phoebe's Husband\n\n\nThe One With Phoebe's Husband\n\n\nOriginally written by Alexa Junge\nTranscribed by Josh Hodge. \n\n\n\n[Scene",
#        'STRANGER', 'DUNCAN', 'RAHCEL',
#        '\n\nThe One With Five Steaks and an Eggplant\n\n\nThe One With Five Steaks and an Eggplant\n\n\nOriginally written by Chris Brown \nTranscribed by Mindy Mattingly Phillips [mmatting@indiana.edu]\nMinor additions and adjustments by Dan Silverstein. \n\n\n[Scene',
#        'JADE', 'MACHINE', 'STEVE', 'WAITRESS',
#        '\n\nThe One With the Baby on the Bus\n\n\nThe One With the Baby on the Bus\n\n\nOriginally written by Betsy Borns\nTranscribed by Mindy Mattingly Phillips [mmatting@indiana.edu]\nMinor additions and adjustments by Dan Silverstein. \n\n\n[Scene',
#        'TERRY', 'CAROLINE', 'BOYS', 'BUS', 'STEPHANIE', 'TOGETHER',
#        '\n\nThe One Where Ross Finds Out\n\n\nThe One Where Ross Finds Out\n\n\nOriginally written by Michael Borkow\nTranscribed by Josh Hodge\nMinor additions and adjustments by Dan Silverstein.\n\n\n[Scene',
#        'MICH',
#        '\n\nThe One With the Last\n\n\nThe One With the List\n\n\nOriginally written by Marta Kauffman and David Crane\nTrascribed by Mindy Mattingly Phillips [mmatting@indiana.edu]\nMinor additions and adjustments by Dan Silverstein.\n\n\n\n[Scene',
#        'RTST', 'holidays', 'one', 'two', 'three', 'four', 'five', 'six',
#        'RADIO',
#        "\n\nThe One With Phoebe's Dad\n\n\nThe One With Phoebe's Dad\n\n\nOriginally written by Jeffrey Astroff and Mike Sikowitz\nTranscribed by Josh Hodge.\nMinor additions and adjustments by Dan SIlverstein.\n\n\n[Scene",
#        'GRANDMOTHER', 'theme', 'idea', 'Video', 'Leader', 'Boss',
#        'Kaplan', 'Sisters', 'Cookie', 'Grandmother', 'Sister', 'Jeannine',
#        'Julio', 'Quartet', 'Barber', 'Singer', 'Richard', 'be', 'Robert',
#        'nods', 'Date', 'called', 'Ginger', 'Lecturer', 'heard', 'is',
#        'Commercial', 'Issac', 'Chloe', 'Sergei', 'Mischa', '10', 'Sophie',
#        'Jasmine', 'Frank', 'Alice', 'Pete', 'Walker', 'Secretary',
#        'Employee', 'Kate', 'Spokeswoman', 'Machine', '7', 'Michelle',
#        'Whitfield', 'Joanna', 'Lauren', 'Anchorwoman', 'Bathroom',
#        'Tommy', 'Cailin', 'Manager', 'Vince', 'Jason', 'Rhodes',
#        'Johnson', 'Mom', 'Fireman', 'Saj', 'office', 'Crystal',
#        'Williams', 'Billy', 'Robin', 'are', 'Doug', 'Hoshi', 'Bonnie',
#        'Phil', 'Stevens', 'Referee', 'Sr', 'Malcom', 'comments', 'head',
#        'Isabella', 'Eric', 'King', 'Student', 'Jester', 'Ben', 'Margha',
#        'Drew', 'Conductor', 'Poughkeepsie', 'Worker', 'Train', 'Kathy',
#        'Guide', 'Scientist', 'Zane', 'Waltham', 'Joshua', 'Emily',
#        'Heston', 'Devon', 'Liam', 'Chatracus', 'Treeger', 'Agent',
#        'Burgin', 'Chip', 'Tony', 'Peter', 'Saleslady', 'Marjorie', 'from',
#        'Stripper', 'Vendor', 'Fergie', 'Housekeeper', 'Felicity',
#        'Passenger', 'Minister', 'Minster', 'Salesman', 'Oven', 'room',
#        'Rick', 'Officer', 'Lambert', 'Potter', 'Simon', 'Interviewer',
#        'Josh', 'Cheryl', 'Everyone', 'Burkart', 'Casey', 'Burke', 'Tim',
#        'Posner', 'Lynch', 'Allesandro', 'By', 'shelf', 'Danny', 'Krista',
#        'Hornswoggle', 'Elizabeth', 'Kara', 'Pastor', 'Ledbetter', 'Katie',
#        'Guests', 'Cop', 'Gary', 'Saleswoman', 'Radio', 'Jen', 'Kim',
#        'Nancy', 'Kyle', 'Raymond', '11', 'Caitlin', 'Dave', 'Miller',
#        'Stanley', 'Grip', 'Husband', 'Tourist', 'Croupier', 'Dealer',
#        'Twin', 'Gambler', 'Lurker', 'Guard', 'Harad', 'Dan', 'Emeril',
#        'Volunteer', 'Collins', 'Inspector', 'Larry', 'Tom', 'Paramedic',
#        'Cynthia', 'Leedbetter', 'Croupler', 'Hitchhiker', 'Janine',
#        'Head', 'Patron', 'Customers', 'Fan', 'Buffay', 'Layer', 'Vampire',
#        'Boyfriend', 'Back', 'Wesley', 'Remoray', 'Hope', 'Arthur',
#        'Instructor', 'Burt', 'Dana', 'Mel', 'Feesen', 'Sebastian',
#        'Eldad', 'Patrick', 'Hint', 'Stephanie', 'Karin', 'Meg', 'Russell',
#        'Producer', 'Wayne', 'Cleaner', 'Official', 'Jeweler', 'Thompson',
#        'Zoe', 'Lisa', 'Alexander', 'Bowmont', 'Narrator', 'Roommate',
#        'Professor', 'Member', 'Alex', 'Owner', 'Judge', 'Passerby',
#        'Park', 'Perk', 'Hillary', 'Guest', 'Millie', 'Tag', 'Detector',
#        'Supervisor', 'Earl', 'Tasks', 'reads', 'Marge', 'to', 'Sportscar',
#        'Dina', 'Lockhart', 'Cecilia', 'Writer', 'Fredrick', 'Perry',
#        'Kudrow', 'Kristen', 'Megan', 'Lewis', 'Morse', 'Jake',
#        'Presenter', 'Ashley', 'Cassie', 'Melissa', 'Drag', 'Helena',
#        'Policeman', 'Line', 'Rabbi', 'Mac', '12', 'Hilda', 'Photographer',
#        'Pees', 'Whitney', 'Erin', 'Colonel', 'Librarian', 'Knocker',
#        'Bandleader', 'Mona', 'Phillips', 'Funny', 'funny', 'Gert',
#        'Styler', 'Schiff', 'Locksmith', 'Long', 'before', 'Don', 'Jim',
#        'color', 'Parker', '106', '304', '322', '204', '703', '603', '507',
#        '417', '521', '604', '609', '619', '711', '214', '618', '224',
#        '512', '401', '513', '712', '722', '608', '706', '413', '605',
#        '613', '607', 'Wedding', 'Ray', 'admits', 'Cashier', 'Critic',
#        'effective', 'Marc', 'Bitch', 'Bastard', 'Birth', 'Cliff', 'Sid',
#        'Franklin', 'Ramoray', 'Kash', 'Kids', 'Witch', 'Clown', 'Cowgirl',
#        'Ballerina', 'Cape', 'Lapse', 'Daughter', 'Brenda', 'understand',
#        'Hooker', 'Stu', 'here', 'Will',
#        '\n\nFriends 910 - The One With Christmas In Tulsa\n\n\n\n<!--\n\nbody {\n  position     ',
#        'Aired', 'exclaiming', 'Wendy', 'Others', 'Claudia', 'Ken',
#        'forth', 'case', 'around', 'Gavin', 'said', 'Extra', 'extra',
#        'Molly', 'Heather', 'girl', 'Sonia', 'friend',
#        '\n\n914 The One With the Blind Dates\n\n\n914 The One With the Blind Dates\n\nWritten by Sherry Bilsing-Graham & Ellen Plummer\nTranscribed by Marita Bakken\n\n[Scene',
#        'night', 'Intern', 'Lennart', 'listen', 'also', 'Mugger',
#        'positive', 'look', 'book', 'do', 'that', 'Handyman',
#        '\n\nFriends 917 - The One With The Memorial Service\n\n\n\n<!--\n\nbody {\n  position     ',
#        'yourself', 'Apartment', 'apartment', 'discuss', 'man', 'Manny',
#        'speech', 'Kori',
#        '\n\n\nFriends - 918 - The one with the lottery\n\n<!--body {  position    ',
#        'Teleplay', 'Story', 'Racel', 'now', 'Message', 'message', 'up',
#        "\n\n\nFriends 919 - The one with Rachel's dream\n\n\n\n\n\n<!--\n\n\n\nbody {\n\n  position     ",
#        'Lassiter', 'lapse', 'Chandlers', 'example', 'McKenna',
#        '\n\n\nFriends - 920 - The one with the soap opera party\n<!--body {  position     ',
#        'Spafford', 'Lowder', 'lady', 'One', 'too', 'Ashford', 'Rache',
#        'Dirk', '16', 'mind', 'woman',
#        '\n\n\nFriends - The one with the fertility test\n   <!--  body {   position     ',
#        'say',
#        '\n\n\nFriends - 922 - The one with the donor\n<!--body {  position     ',
#        'Connelly', 'Sherman', 'Zack', 'Stranger', 'Jeanette',
#        '\n\n\nFriends - 923-924 - The one in Barbados\n<!--body {  position     ',
#        'MOnica', 'line', 'discovered', 'tie', 'Steele', 'Oberblau',
#        'Paleontologist', 'ergaster', 'Ellen', 'Gettleman', 'Sally', 'Boy',
#        'goes', 'TO', 'Hayley', 'roommate', 'everyone', 'request',
#        'Waiters', 'alphabet', 'kitchen', 'nanny', 'at', 'about',
#        'Catherine', 'parents', 'Bitsy', 'Theodore', 'experience',
#        'animals', 'rich',
#        "\n\n908 - The One With Rachel's Other Sister\n\n\n\n908 - The One With Rachel's Other Sister \n\n[Scene",
#        'announcer', 'door', 'shocked', 'face', 'hair', 'laughs',
#        'rejected', 'down', 'bathroom', 'happy', 'plate', 'attack', 'hand',
#        'air', 'phone', 'ear', 'over', 'time', 'crying', 'cry', 'week',
#        'LYNN', 'cute', 'MIKE', 'BILL', 'KEVIN'], dtype=object)

# %%
df['char'].replace({'Chandler':'Chandler','CHANDLER':'Chandler', 'Chandlers':'Chandler', 'chandler': 'Chandler',
                    'Joey':'Joey', 'JOEY': 'Joey',
                    'Monica':'Monica','MONICA':'Monica', 'MOnica': 'Monica', 'MNCA': 'Monica',
                    'Phoebe':'Phoebe','PHOEBE':'Phoebe', 'Pheebs':'Phoebe', 'Pheebs':'Phoebe',
                    'Rachel':'Rachel','RACHEL':'Rachel', 'RACH':'Rachel', 'RAHCEL':'Rachel', 'Racel':'Rachel', 'Rache':'Rachel',
                    'Ross':'Ross', 'RUSS':'Ross', 'ROSS': 'Ross'}, inplace=True)

# %%
char = ['Chandler', 'Joey', 'Monica', 'Phoebe', 'Rachel', 'Ross']
df = df[df['char'].isin(char)]

# %%
df
# Out:
#       season episode      char  \
# 3          1       1    Monica
# 4          1       1      Joey
# 5          1       1  Chandler
# 6          1       1    Phoebe
# 7          1       1    Phoebe
# ...      ...     ...       ...
# 61842      9       9      Ross
# 61843      9       9    Rachel
# 61844      9       9      Ross
# 61846      9       9      Ross
# 61848      9       9    Phoebe
#
#                                                     line
# 3       There's nothing to tell! He's just some guy\n...
# 4       C'mon, you're going out with the guy! There's...
# 5       All right Joey, be\nnice.  So does he have a ...
# 6       Wait, does he eat chalk?\n(They all stare, be...
# 7       Just, 'cause, I don't want her to go through\...
# ...                                                  ...
# 61842                   (holds up the message) Uh, Rach.
# 61843                      (still looking at Emma) Yeah?
# 61844   (pauses, then crunches up the note and stuffs...
# 61846                          Hey you guys.� (He sits.)
# 61848   Hey.� I'll be right back.� I've got to go to ...
#
# [50925 rows x 4 columns]

# %%
df['sentiment'] = df['line'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df['season'] = df['season'].apply(lambda x: int(x))
df['episode'] = df['episode'].apply(lambda x: int(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50925 entries, 3 to 61848
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   season     50925 non-null  int64
#  1   episode    50925 non-null  int64
#  2   char       50925 non-null  object
#  3   line       50925 non-null  object
#  4   sentiment  50925 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.3+ MB

# %%
conn = sqlite3.connect('friends_script.db') #connect to the database
cur = conn.cursor()
cur.execute('CREATE TABLE IF NOT EXISTS Friends(season number, episode number, char text, line text, sentiment integer)')
conn.commit()

# %%
df.to_sql('Friends', conn, if_exists='replace', index=False) # save into the 'lines' table

# %%
COLORS=['#40E0D0', '#4682B4', '#708090', '#90EE90', '#FFDEAD', '#E9967A']

# %% [markdown]
# ## The Most Popular Friend

# %%
cur.execute("SELECT char, COUNT(line) AS 'spoken_lines' FROM Friends GROUP BY char ORDER BY spoken_lines DESC")
most_lines = [c for c in cur.fetchall()]

# %%
plt.rcParams['figure.figsize'] = (10, 6)
fig, ax = plt.subplots()
plt.bar(
    x=[line[0] for line in most_lines],
    height=[line[1] for line in most_lines],
    color=COLORS
)
plt.title('Number of Lines for the Entire Show')
plt.ylabel('No. of Lines')
fig.tight_layout()

# %% [markdown]
# ## Number of lines per season

# %%
cur.execute("SELECT char, season, count(line) AS total_lines FROM Friends WHERE char IN ('Rachel', 'Ross', 'Monica','Chandler','Joey', 'Phoebe') GROUP BY season, char")
lines_per_season = [c for c in cur.fetchall()]

# %%
lines_dict = {}
for lines in lines_per_season:
    char = lines[0]
    season = lines[1]
    total_lines = lines[2]
    
    if char in lines_dict:
        # append the new number to the existing array at this slot
        lines_dict[char][season] = total_lines
    else:
        # create a new array in this slot
        lines_dict[char] = {
            season: total_lines
        }

# %%
fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = (16, 10)
for char in lines_dict.keys():
    x1 = lines_dict[char].keys()
    y1 = lines_dict[char].values()
    plt.plot(x1, y1, label = char)
    
plt.xlabel('Season')
plt.ylabel('Number of Lines')
plt.title('Number of lines by season')
plt.legend(loc=1)
plt.show()

# %% [markdown]
# ### Most Spoken About

# %%
nicknames = [['Rachel', 'Rach'], 
             ['Ross', 'Ross-A-Tron', 'Professor Geller'], 
             ['Monica', 'Mon'],
             ['Chandler', 'Chan'],
             ['Joey', 'Joe'], 
             ['Phoebe', 'Phoebes']]

# %%
all_lines = pd.read_sql("SELECT line FROM Friends", conn)

# %%
char_mention = [] 

for name_list in nicknames:    # loop for each character
    mention_counter = 0        # keep track of the mentions
    for name in name_list:     # loop for each nickname
        mentions = all_lines['line'].str.count(name).sum()
        mention_counter += mentions
    char_mention.append([name_list[0], mention_counter]) #append the name and mention count

# %%
char_mention = sorted(char_mention, key=lambda x: x[1], reverse=True)
char_mention
# Out:
# [['Joey', 5815],
#  ['Chandler', 5233],
#  ['Rachel', 5095],
#  ['Monica', 4967],
#  ['Ross', 3058],
#  ['Phoebe', 1827]]

# %%
plt.rcParams['figure.figsize'] = (10, 6)
fig, ax = plt.subplots()
plt.bar(
    x=[mention[0] for mention in char_mention],
    height=[mention[1] for mention in char_mention],
    color=COLORS
)
plt.title('Number of mentions in the script')
plt.ylabel('No. of mentions')
fig.tight_layout()

# %% [markdown]
# ### Largest Vocabulary

# %%
# function to remove all non alphabetical characters keep spaces
def alphanumonly(text):
    '''Remove all non letters from string'''
    regex = re.compile('[^a-zA-Z ]')
    #First parameter is the replacement, second parameter is your input string
    return(regex.sub('', text))

# %%
cur.execute("SELECT char, line FROM Friends WHERE char IN ('Rachel', 'Ross', 'Monica','Chandler','Joey', 'Phoebe')")
lines_per_season = [c for c in cur.fetchall()]

# %%
monica_vocab = set()
chandler_vocab = set()
ross_vocab = set()
phoebe_vocab = set()
rachel_vocab = set()
joey_vocab = set()

for l in lines_per_season:
    char = l[0]
    l = alphanumonly(l[1]).strip()
    split_words = l.split(' ')
    for word in split_words:
        if char == 'Monica':
            monica_vocab.add(word)
            
        if char == 'Joey':
            joey_vocab.add(word)
        
        if char == 'Ross':
            ross_vocab.add(word)
        
        if char == 'Phoebe':
            phoebe_vocab.add(word)
        
        if char == 'Chandler':
            chandler_vocab.add(word)
        
        if char == 'Rachel':
            rachel_vocab.add(word)

char_vocal_length = ['Ross', 'Joey', 'Chandler', 'Rachel', 'Phoebe', 'Monica']
vocab_lengths = [len(ross_vocab), len(joey_vocab), len(chandler_vocab), len(rachel_vocab), len(phoebe_vocab), len(monica_vocab)]

# %%
plt.rcParams['figure.figsize'] = (10, 6)
fig, ax = plt.subplots()
plt.bar(
    x=char_vocal_length,
    height=vocab_lengths,
    color=COLORS
)
plt.title('Largest Vocabulary')
plt.ylabel('Number of unique words')
fig.tight_layout()

# %% [markdown]
# ## Ross and Rachel Sentiments throughout the season

# %%
cur.execute("SELECT season, episode, sentiment FROM Friends WHERE char == 'Ross' ORDER BY season, episode")
ross_sentiments = [c for c in cur.fetchall()]

# %%
ross_sentiment = {}

for r in ross_sentiments:
    season_episode = f'S{r[0]}E{r[1]}'
    if r[0] == 10:
        season_episode = f'STENE{r[1]}'
    sentiment = r[2]
    if season_episode in ross_sentiment:
        ross_sentiment[season_episode] += sentiment
    else:
        ross_sentiment[season_episode] = sentiment

ross_sentiment
# Out:
# {'S1E1': 3.9649188311688315,
#  'S1E2': 6.851905964405965,
#  'S1E3': 1.8016384078884082,
#  'S1E4': 3.4509469696969695,
#  'S1E5': 4.291338834776336,
#  'S1E6': 0.13690476190476186,
#  'S1E7': 4.304414682539682,
#  'S1E8': 3.169814814814815,
#  'S1E9': 0.9853245464852607,
#  'S1E10': 3.698358585858586,
#  'S1E11': 3.325977891156463,
#  'S1E12': 7.90327380952381,
#  'S1E13': -1.0895833333333331,
#  'S1E14': 1.4092341686091685,
#  'S1E15': 5.113958333333332,
#  'S1E16': 0.7143452380952381,
#  'S1E17': 1.987797619047619,
#  'S1E18': 4.076309523809525,
#  'S1E19': 1.7781349206349202,
#  'S1E20': 1.0004464285714285,
#  'S1E21': -0.8719047619047623,
#  'S1E22': 3.407251082251082,
#  'S1E23': 4.65413029100529,
#  'S1E24': 3.064583333333333,
#  'S2E1': 2.681626984126984,
#  'S2E2': 2.183333333333333,
#  'S2E3': 1.6086309523809523,
#  'S2E4': 3.180803571428572,
#  'S2E5': 9.509334415584416,
#  'S2E6': -1.2909801136363641,
#  'S2E7': 2.6925000000000003,
#  'S2E8': 0.5724702380952382,
#  'S2E9': 3.631374007936508,
#  'S2E10': 3.0888888888888895,
#  'S2E11': 7.099918831168831,
#  'S2E12': 1.4615706168831164,
#  'S2E13': 2.4726851851851857,
#  'S2E14': 1.9313492063492061,
#  'S2E15': 1.2896825396825395,
#  'S2E16': -1.147005772005772,
#  'S2E17': 0.8479166666666667,
#  'S2E18': 3.5424532312925168,
#  'S2E19': 7.348078703703703,
#  'S2E20': 1.026739417989418,
#  'S2E21': 2.9357142857142855,
#  'S2E22': -0.09999999999999995,
#  'S2E23': 1.514880952380952,
#  'S3E1': 3.6452777777777774,
#  'S3E2': 10.034348544973541,
#  'S3E3': 1.9482142857142857,
#  'S3E4': 0.8302430555555554,
#  'S3E5': 4.577847222222222,
#  'S3E6': 1.3010296416546416,
#  'S3E7': 7.965416666666668,
#  'S3E8': 3.7839285714285715,
#  'S3E9': 5.09475033068783,
#  'S3E10': 4.518344907407406,
#  'S3E11': 5.782189153439153,
#  'S3E12': 2.675022246272246,
#  'S3E13': 3.549834656084655,
#  'S3E14': 3.4690909090909092,
#  'S3E15': 3.6983928571428577,
#  'S3E16': 3.953030283374033,
#  'S3E17': 6.926822820037105,
#  'S3E18': 0.40023809523809517,
#  'S3E19': 2.9753043831168835,
#  'S3E20': -0.4354166666666667,
#  'S3E21': 6.006339285714285,
#  'S3E22': 0.3186507936507935,
#  'S3E23': -0.7200892857142858,
#  'S3E24': 3.083878968253968,
#  'S3E25': 5.249173073743386,
#  'S4E1': 2.9120188492063495,
#  'S4E2': 1.8930668290043287,
#  'S4E3': 0.44999999999999996,
#  'S4E4': 2.1305555555555555,
#  'S4E5': 3.100390565948602,
#  'S4E6': 1.2526594932844932,
#  'S4E7': 3.483723673812959,
#  'S4E8': 1.9843749999999996,
#  'S4E9': 1.4133333333333333,
#  'S4E10': 2.2935290404040405,
#  'S4E11': 1.4539236111111111,
#  'S4E12': 2.593690476190476,
#  'S4E13': 4.200793650793651,
#  'S4E14': 2.1300793650793652,
#  'S4E15': 2.197632275132275,
#  'S4E16': 0.6976998299319728,
#  'S4E17': 5.075395021645022,
#  'S4E18': 2.0651875901875902,
#  'S4E19': 2.987439123376623,
#  'S4E20': 4.4305803571428575,
#  'S4E21': 8.290541275853776,
#  'S4E22': 9.139032738095239,
#  'S4E23': 7.81505349251443,
#  'S5E1': 4.717519531249999,
#  'S5E2': 1.243046061197917,
#  'S5E3': 1.58015873015873,
#  'S5E4': 3.4303598484848488,
#  'S5E5': 0.744960317460317,
#  'S5E6': 4.058147997835498,
#  'S5E7': 3.4441738816738807,
#  'S5E8': 1.9969477513227512,
#  'S5E9': 0.9593650793650793,
#  'S5E10': 3.2580148208273205,
#  'S5E11': 5.83103896103896,
#  'S5E12': 5.23328373015873,
#  'S5E13': 0.4695719954648526,
#  'S5E14': 3.2041801948051947,
#  'S5E15': 5.08932705026455,
#  'S5E16': 5.336930708180708,
#  'S5E17': 2.1593750000000003,
#  'S5E18': 1.8629526289682543,
#  'S5E19': 7.1465773809523805,
#  'S5E20': 7.049799219877344,
#  'S5E21': 0.8416418650793652,
#  'S5E22': 0.30680555555555555,
#  'S5E23': 7.5364955357142875,
#  'S6E1': 2.742472718253968,
#  'S6E2': 1.3353813968769324,
#  'S6E3': 6.240145818302068,
#  'S6E4': 4.136051587301586,
#  'S6E5': 2.727794312169313,
#  'S6E6': 0.13289682539682524,
#  'S6E7': 2.2579545454545453,
#  'S6E8': 0.9542929292929292,
#  'S6E9': 5.5442559523809525,
#  'S6E10': 1.8616269147519149,
#  'S6E11': 3.7121916711760465,
#  'S6E12': 0.0007936507936508741,
#  'S6E13': 2.2561183261183255,
#  'S6E14': 7.367807539682539,
#  'S6E15': 6.892138624902296,
#  'S6E16': 3.4150669642857143,
#  'S6E17': 3.3492814625850342,
#  'S6E18': 4.636041666666666,
#  'S6E19': 3.144568452380953,
#  'S6E20': 1.997383432539683,
#  'S6E21': 4.645545634920635,
#  'S6E22': 0.10297619047619089,
#  'S6E23': 4.761228174603174,
#  'S7E1': 7.332939814814815,
#  'S7E2': 1.5032242063492063,
#  'S7E3': 3.1125000000000003,
#  'S7E4': 3.4048363095238092,
#  'S7E5': 5.435342261904761,
#  'S7E6': 4.376649925595238,
#  'S7E7': 1.8975325963718819,
#  'S7E8': -1.1449776785714287,
#  'S7E9': 5.605654761904761,
#  'S7E10': 3.961932043650793,
#  'S7E11': 3.5705563822751323,
#  'S7E12': 3.6966036355619685,
#  'S7E13': 4.728335381343193,
#  'S7E14': 5.103344381313131,
#  'S7E15': 0.9948660714285714,
#  'S7E16': 2.485347222222222,
#  'S7E17': 7.484462610801895,
#  'S7E18': 1.2181836380385487,
#  'S7E19': 0.9714774981962482,
#  'S7E20': 1.4303571428571429,
#  'S7E21': 1.6557291666666667,
#  'S7E22': 2.931969246031746,
#  'S7E23': 5.394982542259327,
#  'S8E1': 3.4116834050539415,
#  'S8E2': -0.5371392496392495,
#  'S8E3': 8.250686383928572,
#  'S8E4': 9.768343253968252,
#  'S8E5': 2.3086656746031746,
#  'S8E6': -0.25664682539682526,
#  'S8E7': 2.4316558441558436,
#  'S8E8': 2.8725694444444447,
#  'S8E9': 1.4567460317460315,
#  'S8E10': 0.5541997354497354,
#  'S8E11': 4.1566242784992795,
#  'S8E12': 1.9618749999999998,
#  'S8E13': 3.971130952380952,
#  'S8E14': 4.109834956709957,
#  'S8E15': 3.9690575396825403,
#  'S8E16': 2.743154761904762,
#  'S8E17': 1.1740079365079363,
#  'S8E18': 5.673014069264068,
#  'S8E19': 2.101662257495591,
#  'S8E20': 6.731895179473306,
#  'S8E21': 3.8380934343434348,
#  'S8E22': 3.1541914682539685,
#  'S8E23': 10.37361832611833,
#  'S9E1': 0.4089087301587301,
#  'S9E2': 3.4492063492063485,
#  'S9E3': 0.592857142857143,
#  'S9E4': 1.6788492063492066,
#  'S9E5': 5.735298859126984,
#  'S9E6': 2.7124140211640215,
#  'S9E7': 0.7334432291666667,
#  'S9E8': 3.1883207070707074,
#  'S9E9': 3.757142857142857,
#  'S9E10': 1.2801136363636365,
#  'S9E11': 1.9463624338624337,
#  'S9E12': 3.3151785714285715,
#  'S9E13': 6.777040240575397,
#  'S9E14': -1.8836805555555554,
#  'S9E15': 2.391982323232323,
#  'S9E16': 2.287544642857143,
#  'S9E17': 1.6662102423039928,
#  'S9E18': 9.62287326388889,
#  'S9E19': 1.4255681818181816,
#  'S9E20': 2.3139479617604612,
#  'S9E21': 5.103099747474748,
#  'S9E22': 1.1359176587301587,
#  'S9E23': 10.244968434343438,
#  'STENE1': 4.293204365079366,
#  'STENE2': 6.809840818903319,
#  'STENE3': -1.411504761904762,
#  'STENE4': 5.24044312169312,
#  'STENE5': 0.18958333333333297,
#  'STENE6': -2.1215367965367964,
#  'STENE7': 6.687369227994227,
#  'STENE8': 2.1364565295815297,
#  'STENE9': 2.8361111111111117,
#  'STENE10': 4.570305735930737,
#  'STENE11': 1.3354166666666667,
#  'STENE12': -1.0179050925925928,
#  'STENE13': 5.112577561327561,
#  'STENE14': 5.307162698412699,
#  'STENE15': 7.197588383838385,
#  'STENE16': 3.352425595238095,
#  'STENE17': 12.098353174603172}

# %%
seasons = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'STEN']

fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = (16, 10)

for season in seasons:
    sentiments = list(filter(lambda item: item[0].startswith(season), ross_sentiment.items())) 
    x1 = list(range(1, len(sentiments)+1))
    y1 = [x[1] for x in sentiments]
    plt.plot(x1, y1, label = season)
    
plt.xlabel('Episode')
plt.ylabel('Number of Lines')
plt.title('Number of lines by season')
plt.legend(loc=1)
plt.show()
